# %% [markdown]
# # Streaming Consumer for Measuring Latency

# %%
from pykafka import KafkaClient
import numpy as np
import msgpack
import msgpack_numpy as m
import time
import datetime
import dateutil.parser
m.patch()

zkKafka='c251-102.wrangler.tacc.utexas.edu:2181'
client = KafkaClient(zookeeper_hosts=zkKafka)
#client = KafkaClient(hosts='c251-142.wrangler.tacc.utexas.edu:9092')
topic = client.topics['latency']
producer = topic.get_sync_producer()
consumer = topic.get_simple_consumer()

# %%
run_timestamp=datetime.datetime.now()
RESULT_FILE= "results/kafka-latency-" + run_timestamp.strftime("%Y%m%d-%H%M%S") + ".csv"
try:
    os.makedirs("results")
except:
    pass
output_file=open(RESULT_FILE, "w")

# %%
while True:
    message = consumer.consume(block=True)
    #print message.value
    now = time.time()
    #sent_time=datetime.datetime.strptime(message.value, "%Y-%m-%dT%H:%M:%S.%fZ")
    sent_time_string = message.value.split(";")[0]
    sleep_time =float(message.value.split(";")[1])
    sent_time = dateutil.parser.parse(sent_time_string)
    sent_time_ts = time.mktime(sent_time.timetuple())
    lat = now-sent_time_ts    
    result = "kafka, latency, %.5f, %.5f\n"%(1/sleep_time, lat)
    print(result)
    output_file.write(result)
    output_file.flush()
# Out:
# kafka, latency, 1.00000, 1.44473
#
# kafka, latency, 1.00000, 0.10976
#
# kafka, latency, 1.00000, 0.14150
#
# kafka, latency, 1.00000, 0.25543
#
# kafka, latency, 1.00000, 0.27114
#
# kafka, latency, 1.00000, 0.28690
#
# kafka, latency, 1.00000, 0.40093
#
# kafka, latency, 1.00000, 0.43285
#
# kafka, latency, 1.00000, 0.44046
#
# kafka, latency, 1.00000, 0.60446
#
# kafka, latency, 1.00000, 0.60478
#
# kafka, latency, 1.00000, 0.71871
#
# kafka, latency, 1.00000, 0.72638
#
# kafka, latency, 1.00000, 0.75821
#
# kafka, latency, 1.00000, 0.76589
#
# kafka, latency, 1.00000, 0.79772
#
# kafka, latency, 1.00000, 0.91184
#
# kafka, latency, 1.00000, 0.92762
#
# kafka, latency, 1.00000, 0.94333
#
# kafka, latency, 1.00000, 0.95912
#
# kafka, latency, 10.00000, 0.99107
#
# kafka, latency, 10.00000, 0.20513
#
# kafka, latency, 10.00000, 0.41924
#
# kafka, latency, 10.00000, 0.63340
#
# kafka, latency, 10.00000, 0.79740
#
# kafka, latency, 10.00000, 1.01140
#
# kafka, latency, 10.00000, 0.22542
#
# kafka, latency, 10.00000, 0.43953
#
# kafka, latency, 10.00000, 0.65356
#
# kafka, latency, 10.00000, 0.86769
#
# kafka, latency, 10.00000, 1.03161
#
# kafka, latency, 10.00000, 0.24561
#
# kafka, latency, 10.00000, 0.45967
#
# kafka, latency, 10.00000, 0.67370
#
# kafka, latency, 10.00000, 0.88773
#
# kafka, latency, 10.00000, 1.05168
#
# kafka, latency, 10.00000, 0.26569
#
# kafka, latency, 10.00000, 0.47974
#
# kafka, latency, 10.00000, 0.69380
#
# kafka, latency, 10.00000, 0.90789
#
# kafka, latency, 100.00000, 1.07185
#
# kafka, latency, 100.00000, 0.18570
#
# kafka, latency, 100.00000, 0.29959
#
# kafka, latency, 100.00000, 0.41344
#
# kafka, latency, 100.00000, 0.52738
#
# kafka, latency, 100.00000, 0.59116
#
# kafka, latency, 100.00000, 0.70499
#
# kafka, latency, 100.00000, 0.81891
#
# kafka, latency, 100.00000, 0.93274
#
# kafka, latency, 100.00000, 0.99653
#
# kafka, latency, 100.00000, 0.11040
#
# kafka, latency, 100.00000, 0.22425
#
# kafka, latency, 100.00000, 0.33814
#
# kafka, latency, 100.00000, 0.45199
#
# kafka, latency, 100.00000, 0.51577
#
# kafka, latency, 100.00000, 0.62960
#
# kafka, latency, 100.00000, 0.74340
#
# kafka, latency, 100.00000, 0.85724
#
# kafka, latency, 100.00000, 0.97106
#
# kafka, latency, 100.00000, 1.03484
#
# kafka, latency, 1000.00000, 0.14868
#
# kafka, latency, 1000.00000, 0.26247
#
# kafka, latency, 1000.00000, 0.37632
#
# kafka, latency, 1000.00000, 0.44003
#
# kafka, latency, 1000.00000, 0.55383
#
# kafka, latency, 1000.00000, 0.66767
#
# kafka, latency, 1000.00000, 0.78147
#
# kafka, latency, 1000.00000, 0.84527
#
# kafka, latency, 1000.00000, 0.95913
#
# kafka, latency, 1000.00000, 1.07293
#
# kafka, latency, 1000.00000, 0.18679
#
# kafka, latency, 1000.00000, 0.30060
#
# kafka, latency, 1000.00000, 0.36439
#
# kafka, latency, 1000.00000, 0.47819
#
# kafka, latency, 1000.00000, 0.59202
#
# kafka, latency, 1000.00000, 0.70590
#
# kafka, latency, 1000.00000, 0.76967
#
# kafka, latency, 1000.00000, 0.88346
#
# kafka, latency, 1000.00000, 0.99740
#
# kafka, latency, 1000.00000, 1.11124
#
# kafka, latency, 10000.00000, 0.22523
#
# kafka, latency, 10000.00000, 0.28900
#
# kafka, latency, 10000.00000, 0.40285
#
# kafka, latency, 10000.00000, 0.51670
#
# kafka, latency, 10000.00000, 0.63061
#
# kafka, latency, 10000.00000, 0.69435
#
# kafka, latency, 10000.00000, 0.80817
#
# kafka, latency, 10000.00000, 0.92199
#
# kafka, latency, 10000.00000, 1.03604
#
# kafka, latency, 10000.00000, 0.14987
#
# kafka, latency, 10000.00000, 0.21367
#
# kafka, latency, 10000.00000, 0.32745
#
# kafka, latency, 10000.00000, 0.44125
#
# kafka, latency, 10000.00000, 0.55513
#
# kafka, latency, 10000.00000, 0.61890
#
# kafka, latency, 10000.00000, 0.73277
#
# kafka, latency, 10000.00000, 0.84669
#
# kafka, latency, 10000.00000, 0.96055
#
# kafka, latency, 10000.00000, 1.07456
#
# kafka, latency, 10000.00000, 0.13828
#
# kafka, latency, 100000.00000, 0.25209
#
# kafka, latency, 100000.00000, 0.36600
#
# kafka, latency, 100000.00000, 0.47980
#
# kafka, latency, 100000.00000, 0.54367
#
# kafka, latency, 100000.00000, 0.65749
#
# kafka, latency, 100000.00000, 0.77133
#
# kafka, latency, 100000.00000, 0.88517
#
# kafka, latency, 100000.00000, 0.99903
#
# kafka, latency, 100000.00000, 1.06278
#
# kafka, latency, 100000.00000, 0.17661
#
# kafka, latency, 100000.00000, 0.29041
#
# kafka, latency, 100000.00000, 0.40427
#
# kafka, latency, 100000.00000, 0.51806
#
# kafka, latency, 100000.00000, 0.58180
#
# kafka, latency, 100000.00000, 0.69560
#
# kafka, latency, 100000.00000, 0.80943
#
# kafka, latency, 100000.00000, 0.92326
#
# kafka, latency, 100000.00000, 0.98698
#
# kafka, latency, 100000.00000, 1.10083
#
# kafka, latency, 100000.00000, 0.21469

# %%
# Out:
# 1479509383.0

# %%
# Out:
# <function strftime>
