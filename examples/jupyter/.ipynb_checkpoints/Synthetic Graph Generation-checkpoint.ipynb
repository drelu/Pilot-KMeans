# %% [markdown]
# # Synthetic Graph Generation
#
# Look at example data from Oliver as base for creating a synthetic, large dataset

# %%
import matplotlib.pyplot as plt
import networkx as NX
import time
import datetime
import os,sys

FILENAME_SMALL="../data/mdanalysis/small/graph_edges_95_215.csv"
FILENAME_MEDIUM="../data/mdanalysis/medium/graph_edges_24056_71826.csv"
OUTPUT_DIR="../data/mdanalysis/large/"
# !head -n 5 {FILENAME_MEDIUM}


start = time.time()
nxg = NX.read_edgelist(FILENAME_MEDIUM, delimiter=",")
end_read = time.time()
NX.draw(nxg, pos=NX.spring_layout(nxg))
# Out:
# 0,0
# 0,17369
# 0,17306
# 0,179
# 0,17446

# %%
degree_sequence=sorted(NX.degree(nxg).values(),reverse=True) # degree sequence
print "Length: %d" % len(degree_sequence)
dmax=max(degree_sequence)
plt.loglog(degree_sequence,'b-',marker='o')
plt.title("Degree Histogram")
plt.ylabel("Degree")
plt.xlabel("Node")
# Out:
# Length: 24056

# %% [markdown]
# # Data Generation

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
series = pd.Series(NX.degree(nxg).values())
series.describe()
# Out:
# count    24056.000000
# mean         5.971566
# std          1.305737
# min          2.000000
# 25%          5.000000
# 50%          6.000000
# 75%          7.000000
# max         12.000000
# dtype: float64

# %%
series.hist()

# %%
number_of_nodes=[10000, 20000, 30000]
for number in number_of_nodes:
    degree_vector = np.random.normal(series.mean(), series.std(), number)
    graph = NX.expected_degree_graph(degree_vector)
    NX.write_edgelist(graph,
                      os.path.join(OUTPUT_DIR, 
                            "graph_edges_%s_%s.csv"%
                                   (str(number), str(NX.number_of_edges(graph)))),
                      delimiter=",")
# Out:
#   File "<ipython-input-39-87a5de8b1b2b>", line 8
#     delimiter=",")
#                   ^
# SyntaxError: invalid syntax

# %%
str(graph.size)
# Out:
# '<bound method Graph.size of <networkx.classes.graph.Graph object at 0x102a0cf10>>'

# %%
# Out:
# 89418

# %%
len(degree_vector)
# Out:
# 30000
